# %%
import random

# %%
# Fitness function - calculates the fitness of a given chromosome
def fitness(chromosome, budget):
    total_cost = sum(chromosome.values())
    return (budget - total_cost) / budget

# %% [markdown]
# ##### test

# %%
for chromosome in population:
    print(sum(chromosome.values()))
    print((budget - sum(chromosome.values())) / budget)
# Out:
# 725
# 0.6375
# 1073
# 0.4635
# 715
# 0.6425
# 772
# 0.614
# 759
# 0.6205
# 855
# 0.5725
# 884
# 0.558
# 1197
# 0.4015
# 880
# 0.56
# 663
# 0.6685
# 823
# 0.5885
# 642
# 0.679
# 821
# 0.5895
# 1167
# 0.4165
# 778
# 0.611
# 899
# 0.5505
# 832
# 0.584
# 969
# 0.5155
# 786
# 0.607
# 577
# 0.7115
# 672
# 0.664
# 1146
# 0.427
# 854
# 0.573
# 1090
# 0.455
# 1129
# 0.4355
# 630
# 0.685
# 1034
# 0.483
# 1047
# 0.4765
# 600
# 0.7
# 1025
# 0.4875
# 1280
# 0.36
# 768
# 0.616
# 384
# 0.808
# 1037
# 0.4815
# 999
# 0.5005
# 876
# 0.562
# 578
# 0.711
# 711
# 0.6445
# 655
# 0.6725
# 624
# 0.688
# 1027
# 0.4865
# 466
# 0.767
# 658
# 0.671
# 380
# 0.81
# 332
# 0.834
# 614
# 0.693
# 827
# 0.5865
# 1145
# 0.4275
# 1051
# 0.4745
# 891
# 0.5545
# 896
# 0.552
# 874
# 0.563
# 1234
# 0.383
# 665
# 0.6675
# 726
# 0.637
# 776
# 0.612
# 788
# 0.606
# 408
# 0.796
# 1013
# 0.4935
# 735
# 0.6325
# 1377
# 0.3115
# 973
# 0.5135
# 480
# 0.76
# 376
# 0.812
# 863
# 0.5685
# 831
# 0.5845
# 1017
# 0.4915
# 745
# 0.6275
# 1140
# 0.43
# 447
# 0.7765
# 1067
# 0.4665
# 796
# 0.602
# 1328
# 0.336
# 347
# 0.8265
# 736
# 0.632
# 1328
# 0.336
# 400
# 0.8
# 618
# 0.691
# 637
# 0.6815
# 674
# 0.663
# 156
# 0.922
# 639
# 0.6805
# 459
# 0.7705
# 527
# 0.7365
# 808
# 0.596
# 621
# 0.6895
# 996
# 0.502
# 993
# 0.5035
# 822
# 0.589
# 735
# 0.6325
# 595
# 0.7025
# 912
# 0.544
# 776
# 0.612
# 874
# 0.563
# 484
# 0.758
# 1070
# 0.465
# 511
# 0.7445
# 867
# 0.5665
# 493
# 0.7535
# 628
# 0.686

# %%
# Selection function - selects two chromosomes from the population based on their fitness
def selection(population, budget):
    fitness_values = [fitness(chromosome, budget) for chromosome in population] 
    sum_fitness = sum(fitness_values)
    selection_probabilities = [fitness_value/sum_fitness for fitness_value in fitness_values]
    index1 = random.choices(range(len(population)), weights=selection_probabilities)[0]
    index2 = random.choices(range(len(population)), weights=selection_probabilities)[0]
    return population[index1], population[index2]

# %% [markdown]
# ##### test

# %%
fitness_values = [fitness(chromosome, budget) for chromosome in population] 
fitness_values
# Out:
# [0.6375,
#  0.4635,
#  0.6425,
#  0.614,
#  0.6205,
#  0.5725,
#  0.558,
#  0.4015,
#  0.56,
#  0.6685,
#  0.5885,
#  0.679,
#  0.5895,
#  0.4165,
#  0.611,
#  0.5505,
#  0.584,
#  0.5155,
#  0.607,
#  0.7115,
#  0.664,
#  0.427,
#  0.573,
#  0.455,
#  0.4355,
#  0.685,
#  0.483,
#  0.4765,
#  0.7,
#  0.4875,
#  0.36,
#  0.616,
#  0.808,
#  0.4815,
#  0.5005,
#  0.562,
#  0.711,
#  0.6445,
#  0.6725,
#  0.688,
#  0.4865,
#  0.767,
#  0.671,
#  0.81,
#  0.834,
#  0.693,
#  0.5865,
#  0.4275,
#  0.4745,
#  0.5545,
#  0.552,
#  0.563,
#  0.383,
#  0.6675,
#  0.637,
#  0.612,
#  0.606,
#  0.796,
#  0.4935,
#  0.6325,
#  0.3115,
#  0.5135,
#  0.76,
#  0.812,
#  0.5685,
#  0.5845,
#  0.4915,
#  0.6275,
#  0.43,
#  0.7765,
#  0.4665,
#  0.602,
#  0.336,
#  0.8265,
#  0.632,
#  0.336,
#  0.8,
#  0.691,
#  0.6815,
#  0.663,
#  0.922,
#  0.6805,
#  0.7705,
#  0.7365,
#  0.596,
#  0.6895,
#  0.502,
#  0.5035,
#  0.589,
#  0.6325,
#  0.7025,
#  0.544,
#  0.612,
#  0.563,
#  0.758,
#  0.465,
#  0.7445,
#  0.5665,
#  0.7535,
#  0.686]

# %%
sum(fitness_values)
# Out:
# 60.19599999999999

# %%
selection_probabilities = [fitness_value/sum(fitness_values) for fitness_value in fitness_values]
selection_probabilities
# Out:
# [0.0105904046780517,
#  0.007699847165924647,
#  0.010673466675526613,
#  0.010200013289919598,
#  0.010307993886636987,
#  0.009510598710877801,
#  0.009269718918200547,
#  0.006669878397235698,
#  0.009302943717190513,
#  0.011105389062396174,
#  0.00977639710279753,
#  0.011279819257093497,
#  0.009793009502292513,
#  0.006919064389660444,
#  0.010150176091434648,
#  0.009145125921988174,
#  0.009701641305070105,
#  0.008563691939663765,
#  0.010083726493454716,
#  0.011819722240680446,
#  0.01103063326466875,
#  0.007093494584357766,
#  0.009518904910625292,
#  0.0075586417702172915,
#  0.007234699980065122,
#  0.011379493654063396,
#  0.008023788956076817,
#  0.007915808359359428,
#  0.01162867964648814,
#  0.00809854475380424,
#  0.005980463818193901,
#  0.010233238088909564,
#  0.013422818791946312,
#  0.007998870356834342,
#  0.00831450594723902,
#  0.00933616851618048,
#  0.011811416040932953,
#  0.01070669147451658,
#  0.011171838660376106,
#  0.011429330852548342,
#  0.008081932354309257,
#  0.012741710412652006,
#  0.011146920061133632,
#  0.013456043590936278,
#  0.01385474117881587,
#  0.011512392850023258,
#  0.009743172303807564,
#  0.007101800784105257,
#  0.007882583560369461,
#  0.009211575519968105,
#  0.00917004452123065,
#  0.00935278091567546,
#  0.0063625490065785115,
#  0.01108877666290119,
#  0.010582098478304209,
#  0.010166788490929632,
#  0.010067114093959733,
#  0.013223469998006514,
#  0.00819821915077414,
#  0.010507342680576784,
#  0.005174762442687222,
#  0.008530467140673799,
#  0.012625423616187124,
#  0.013489268389926245,
#  0.009444149112897869,
#  0.009709947504817597,
#  0.008164994351784173,
#  0.010424280683101868,
#  0.007143331782842714,
#  0.012899528207854343,
#  0.007749684364409597,
#  0.0100006644959798,
#  0.005581766230314308,
#  0.013730148182603498,
#  0.010499036480829293,
#  0.005581766230314308,
#  0.013289919595986447,
#  0.011479168051033292,
#  0.011321350255830955,
#  0.011014020865173769,
#  0.01531663233437438,
#  0.011304737856335971,
#  0.012799853810884446,
#  0.012235032228055023,
#  0.009900990099009903,
#  0.011454249451790818,
#  0.008339424546481495,
#  0.008364343145723969,
#  0.00978470330254502,
#  0.010507342680576784,
#  0.011670210645225599,
#  0.009037145325270784,
#  0.010166788490929632,
#  0.00935278091567546,
#  0.012592198817197158,
#  0.007724765765167122,
#  0.012367931424014888,
#  0.009410924313907902,
#  0.012517443019469733,
#  0.011396106053558378]

# %%
index1 = random.choices(range(len(population)), weights=selection_probabilities)[0]
random.choices(range(len(population)), weights=selection_probabilities)[0]
# Out:
# 45

# %%
# Crossover function - performs a single-point crossover on two chromosomes
def crossover(chromosome1, chromosome2):
    crossover_point = random.randint(0, len(chromosome1)-1) # can choose between 0-5(untuk point yang mana nak crossover)
    new_chromosome1 = { key: (chromosome1[key] if index <= crossover_point else chromosome2[key]) for index, key in enumerate(chromosome1)} # tukar value dict pada point dengan parent2
    new_chromosome2 = { key: (chromosome2[key] if index <= crossover_point else chromosome1[key]) for index, key in enumerate(chromosome2)} # tukar value dict pada point dengan parent1
    return new_chromosome1, new_chromosome2

# %% [markdown]
# ##### test

# %%
population = [{ 'Shopping': random.randint(0, 150), 'Food & Drink': random.randint(0, 250), 'Life & Entertainment': random.randint(0, 150), 'Vehicle': random.randint(0, 200), 'Housing': random.randint(0, 700), 'Education':random.randint(0,150)} for i in range(population_size)]

parent1, parent2 = selection(population, budget)

parent1
# Out:
# {'Shopping': 132,
#  'Food & Drink': 231,
#  'Life & Entertainment': 18,
#  'Vehicle': 89,
#  'Housing': 296,
#  'Education': 89}

# %%
parent2
# Out:
# {'Shopping': 59,
#  'Food & Drink': 108,
#  'Life & Entertainment': 10,
#  'Vehicle': 67,
#  'Housing': 106,
#  'Education': 50}

# %%
crossover_point = random.randint(0, len(parent1)-1)  # can choose between 0-5(untuk point yang mana nak crossover)
new_chromosome1 = { key: (parent1[key] if index <= crossover_point else parent2[key]) for index, key in enumerate(parent1)}
new_chromosome2 = { key: (parent2[key] if index <= crossover_point else parent1[key]) for index, key in enumerate(parent2)} # tukar value dict pada point dengan parent1
new_chromosome2
# Out:
# {'Shopping': 59,
#  'Food & Drink': 108,
#  'Life & Entertainment': 10,
#  'Vehicle': 67,
#  'Housing': 106,
#  'Education': 50}

# %%
# Mutation function - mutates a single gene in the chromosome
def mutation(chromosome, mutation_rate):
    for key in chromosome:
        if random.random() < mutation_rate:
            chromosome[key] += random.randint(-10, 10)
    return chromosome

# %% [markdown]
# ##### test

# %%
for key in new_chromosome1:
    if random.random() < mutation_rate:
        new_chromosome1[key] += random.randint(-10,10)

# %%
# Main function - runs the genetic algorithm
def genetic_algorithm(budget, population_size, generations, mutation_rate):
    # Generate initial population
    population = [{ 'Shopping': random.randint(0, 150), 'Food & Drink': random.randint(250, 300), 'Life & Entertainment': random.randint(100, 150), 'Vehicle': random.randint(200, 400), 'Housing': random.randint(250, 350), 'Education':random.randint(0,150)} for i in range(population_size)]
    best_chromosome = None
    for i in range(generations):
        # Select two parents from the population
        parent1, parent2 = selection(population, budget)
        # Create two children from the parents
        child1, child2 = crossover(parent1, parent2)
        # Mutate the children
        child1 = mutation(child1, mutation_rate)
        child2 = mutation(child2, mutation_rate)
        # Add the children to the population
        population.extend([child1, child2])
        # Keep only the best chromosomes in the population
        population = sorted(population, key=lambda x: fitness(x, budget), reverse=True)[:population_size]
        # Update the best chromosome if necessary
        if best_chromosome is None or fitness(best_chromosome, budget) < fitness(population[0], budget):
            best_chromosome = population[0]
        # Print the best chromosome and its fitness
        print(f"Generation {i+1}: Best chromosome = {best_chromosome}, Fitness = {fitness(best_chromosome, budget)}")
    return best_chromosome

# %%
population.extend([new_chromosome1, new_chromosome2])
population
# Out:
# [{'Shopping': 4,
#   'Food & Drink': 25,
#   'Life & Entertainment': 25,
#   'Vehicle': 70,
#   'Housing': 21,
#   'Education': 11},
#  {'Shopping': 57,
#   'Food & Drink': 23,
#   'Life & Entertainment': 138,
#   'Vehicle': 17,
#   'Housing': 61,
#   'Education': 36},
#  {'Shopping': 137,
#   'Food & Drink': 9,
#   'Life & Entertainment': 83,
#   'Vehicle': 55,
#   'Housing': 35,
#   'Education': 28},
#  {'Shopping': 146,
#   'Food & Drink': 18,
#   'Life & Entertainment': 55,
#   'Vehicle': 2,
#   'Housing': 151,
#   'Education': 4},
#  {'Shopping': 13,
#   'Food & Drink': 7,
#   'Life & Entertainment': 112,
#   'Vehicle': 3,
#   'Housing': 105,
#   'Education': 140},
#  {'Shopping': 1,
#   'Food & Drink': 136,
#   'Life & Entertainment': 42,
#   'Vehicle': 122,
#   'Housing': 16,
#   'Education': 67},
#  {'Shopping': 59,
#   'Food & Drink': 108,
#   'Life & Entertainment': 10,
#   'Vehicle': 67,
#   'Housing': 106,
#   'Education': 50},
#  {'Shopping': 97,
#   'Food & Drink': 84,
#   'Life & Entertainment': 18,
#   'Vehicle': 124,
#   'Housing': 51,
#   'Education': 34},
#  {'Shopping': 60,
#   'Food & Drink': 116,
#   'Life & Entertainment': 20,
#   'Vehicle': 67,
#   'Housing': 106,
#   'Education': 50},
#  {'Shopping': 60,
#   'Food & Drink': 116,
#   'Life & Entertainment': 20,
#   'Vehicle': 67,
#   'Housing': 106,
#   'Education': 50},
#  {'Shopping': 60,
#   'Food & Drink': 116,
#   'Life & Entertainment': 20,
#   'Vehicle': 67,
#   'Housing': 106,
#   'Education': 50},
#  {'Shopping': 60,
#   'Food & Drink': 116,
#   'Life & Entertainment': 20,
#   'Vehicle': 67,
#   'Housing': 106,
#   'Education': 50},
#  {'Shopping': 59,
#   'Food & Drink': 30,
#   'Life & Entertainment': 33,
#   'Vehicle': 139,
#   'Housing': 46,
#   'Education': 140},
#  {'Shopping': 69,
#   'Food & Drink': 50,
#   'Life & Entertainment': 98,
#   'Vehicle': 28,
#   'Housing': 146,
#   'Education': 68},
#  {'Shopping': 141,
#   'Food & Drink': 124,
#   'Life & Entertainment': 121,
#   'Vehicle': 44,
#   'Housing': 5,
#   'Education': 31},
#  {'Shopping': 57,
#   'Food & Drink': 142,
#   'Life & Entertainment': 44,
#   'Vehicle': 2,
#   'Housing': 170,
#   'Education': 65},
#  {'Shopping': 81,
#   'Food & Drink': 82,
#   'Life & Entertainment': 71,
#   'Vehicle': 123,
#   'Housing': 33,
#   'Education': 94},
#  {'Shopping': 75,
#   'Food & Drink': 126,
#   'Life & Entertainment': 63,
#   'Vehicle': 30,
#   'Housing': 57,
#   'Education': 142},
#  {'Shopping': 34,
#   'Food & Drink': 115,
#   'Life & Entertainment': 48,
#   'Vehicle': 128,
#   'Housing': 88,
#   'Education': 98},
#  {'Shopping': 132,
#   'Food & Drink': 72,
#   'Life & Entertainment': 32,
#   'Vehicle': 29,
#   'Housing': 255,
#   'Education': 7},
#  {'Shopping': 74,
#   'Food & Drink': 143,
#   'Life & Entertainment': 99,
#   'Vehicle': 82,
#   'Housing': 170,
#   'Education': 9},
#  {'Shopping': 87,
#   'Food & Drink': 103,
#   'Life & Entertainment': 111,
#   'Vehicle': 46,
#   'Housing': 175,
#   'Education': 56},
#  {'Shopping': 61,
#   'Food & Drink': 176,
#   'Life & Entertainment': 135,
#   'Vehicle': 59,
#   'Housing': 38,
#   'Education': 126},
#  {'Shopping': 20,
#   'Food & Drink': 145,
#   'Life & Entertainment': 50,
#   'Vehicle': 140,
#   'Housing': 191,
#   'Education': 54},
#  {'Shopping': 90,
#   'Food & Drink': 196,
#   'Life & Entertainment': 18,
#   'Vehicle': 143,
#   'Housing': 108,
#   'Education': 59},
#  {'Shopping': 69,
#   'Food & Drink': 190,
#   'Life & Entertainment': 29,
#   'Vehicle': 138,
#   'Housing': 63,
#   'Education': 129},
#  {'Shopping': 45,
#   'Food & Drink': 98,
#   'Life & Entertainment': 12,
#   'Vehicle': 174,
#   'Housing': 243,
#   'Education': 49},
#  {'Shopping': 62,
#   'Food & Drink': 107,
#   'Life & Entertainment': 34,
#   'Vehicle': 166,
#   'Housing': 164,
#   'Education': 91},
#  {'Shopping': 30,
#   'Food & Drink': 245,
#   'Life & Entertainment': 67,
#   'Vehicle': 129,
#   'Housing': 39,
#   'Education': 118},
#  {'Shopping': 124,
#   'Food & Drink': 120,
#   'Life & Entertainment': 13,
#   'Vehicle': 119,
#   'Housing': 159,
#   'Education': 95},
#  {'Shopping': 126,
#   'Food & Drink': 228,
#   'Life & Entertainment': 65,
#   'Vehicle': 31,
#   'Housing': 44,
#   'Education': 143},
#  {'Shopping': 47,
#   'Food & Drink': 156,
#   'Life & Entertainment': 102,
#   'Vehicle': 178,
#   'Housing': 145,
#   'Education': 11},
#  {'Shopping': 39,
#   'Food & Drink': 197,
#   'Life & Entertainment': 120,
#   'Vehicle': 165,
#   'Housing': 43,
#   'Education': 78},
#  {'Shopping': 71,
#   'Food & Drink': 175,
#   'Life & Entertainment': 130,
#   'Vehicle': 92,
#   'Housing': 161,
#   'Education': 26},
#  {'Shopping': 84,
#   'Food & Drink': 4,
#   'Life & Entertainment': 86,
#   'Vehicle': 119,
#   'Housing': 278,
#   'Education': 87},
#  {'Shopping': 87,
#   'Food & Drink': 55,
#   'Life & Entertainment': 99,
#   'Vehicle': 122,
#   'Housing': 229,
#   'Education': 71},
#  {'Shopping': 136,
#   'Food & Drink': 94,
#   'Life & Entertainment': 66,
#   'Vehicle': 46,
#   'Housing': 233,
#   'Education': 90},
#  {'Shopping': 131,
#   'Food & Drink': 242,
#   'Life & Entertainment': 109,
#   'Vehicle': 60,
#   'Housing': 42,
#   'Education': 88},
#  {'Shopping': 86,
#   'Food & Drink': 149,
#   'Life & Entertainment': 148,
#   'Vehicle': 38,
#   'Housing': 186,
#   'Education': 67},
#  {'Shopping': 85,
#   'Food & Drink': 165,
#   'Life & Entertainment': 116,
#   'Vehicle': 50,
#   'Housing': 151,
#   'Education': 144},
#  {'Shopping': 132,
#   'Food & Drink': 77,
#   'Life & Entertainment': 144,
#   'Vehicle': 43,
#   'Housing': 315,
#   'Education': 4},
#  {'Shopping': 122,
#   'Food & Drink': 243,
#   'Life & Entertainment': 87,
#   'Vehicle': 174,
#   'Housing': 69,
#   'Education': 30},
#  {'Shopping': 25,
#   'Food & Drink': 151,
#   'Life & Entertainment': 26,
#   'Vehicle': 83,
#   'Housing': 323,
#   'Education': 118},
#  {'Shopping': 83,
#   'Food & Drink': 100,
#   'Life & Entertainment': 80,
#   'Vehicle': 77,
#   'Housing': 262,
#   'Education': 133},
#  {'Shopping': 77,
#   'Food & Drink': 98,
#   'Life & Entertainment': 79,
#   'Vehicle': 153,
#   'Housing': 257,
#   'Education': 71},
#  {'Shopping': 21,
#   'Food & Drink': 60,
#   'Life & Entertainment': 9,
#   'Vehicle': 32,
#   'Housing': 576,
#   'Education': 38},
#  {'Shopping': 119,
#   'Food & Drink': 105,
#   'Life & Entertainment': 149,
#   'Vehicle': 6,
#   'Housing': 258,
#   'Education': 108},
#  {'Shopping': 145,
#   'Food & Drink': 192,
#   'Life & Entertainment': 5,
#   'Vehicle': 56,
#   'Housing': 298,
#   'Education': 63},
#  {'Shopping': 92,
#   'Food & Drink': 235,
#   'Life & Entertainment': 10,
#   'Vehicle': 35,
#   'Housing': 364,
#   'Education': 32},
#  {'Shopping': 40,
#   'Food & Drink': 224,
#   'Life & Entertainment': 64,
#   'Vehicle': 62,
#   'Housing': 244,
#   'Education': 138},
#  {'Shopping': 29,
#   'Food & Drink': 238,
#   'Life & Entertainment': 135,
#   'Vehicle': 120,
#   'Housing': 145,
#   'Education': 109},
#  {'Shopping': 81,
#   'Food & Drink': 37,
#   'Life & Entertainment': 32,
#   'Vehicle': 193,
#   'Housing': 372,
#   'Education': 61},
#  {'Shopping': 69,
#   'Food & Drink': 102,
#   'Life & Entertainment': 56,
#   'Vehicle': 178,
#   'Housing': 274,
#   'Education': 99},
#  {'Shopping': 55,
#   'Food & Drink': 11,
#   'Life & Entertainment': 21,
#   'Vehicle': 77,
#   'Housing': 563,
#   'Education': 59},
#  {'Shopping': 40,
#   'Food & Drink': 170,
#   'Life & Entertainment': 69,
#   'Vehicle': 161,
#   'Housing': 284,
#   'Education': 64},
#  {'Shopping': 70,
#   'Food & Drink': 50,
#   'Life & Entertainment': 32,
#   'Vehicle': 10,
#   'Housing': 535,
#   'Education': 99},
#  {'Shopping': 121,
#   'Food & Drink': 67,
#   'Life & Entertainment': 22,
#   'Vehicle': 77,
#   'Housing': 503,
#   'Education': 18},
#  {'Shopping': 117,
#   'Food & Drink': 7,
#   'Life & Entertainment': 145,
#   'Vehicle': 127,
#   'Housing': 279,
#   'Education': 146},
#  {'Shopping': 30,
#   'Food & Drink': 198,
#   'Life & Entertainment': 84,
#   'Vehicle': 26,
#   'Housing': 441,
#   'Education': 43},
#  {'Shopping': 74,
#   'Food & Drink': 189,
#   'Life & Entertainment': 91,
#   'Vehicle': 111,
#   'Housing': 345,
#   'Education': 13},
#  {'Shopping': 6,
#   'Food & Drink': 88,
#   'Life & Entertainment': 34,
#   'Vehicle': 86,
#   'Housing': 478,
#   'Education': 135},
#  {'Shopping': 143,
#   'Food & Drink': 161,
#   'Life & Entertainment': 65,
#   'Vehicle': 87,
#   'Housing': 303,
#   'Education': 72},
#  {'Shopping': 16,
#   'Food & Drink': 94,
#   'Life & Entertainment': 18,
#   'Vehicle': 22,
#   'Housing': 566,
#   'Education': 116},
#  {'Shopping': 22,
#   'Food & Drink': 7,
#   'Life & Entertainment': 11,
#   'Vehicle': 147,
#   'Housing': 568,
#   'Education': 99},
#  {'Shopping': 132,
#   'Food & Drink': 231,
#   'Life & Entertainment': 18,
#   'Vehicle': 89,
#   'Housing': 296,
#   'Education': 89},
#  {'Shopping': 132,
#   'Food & Drink': 231,
#   'Life & Entertainment': 18,
#   'Vehicle': 89,
#   'Housing': 296,
#   'Education': 89},
#  {'Shopping': 132,
#   'Food & Drink': 231,
#   'Life & Entertainment': 18,
#   'Vehicle': 89,
#   'Housing': 296,
#   'Education': 89},
#  {'Shopping': 132,
#   'Food & Drink': 231,
#   'Life & Entertainment': 18,
#   'Vehicle': 89,
#   'Housing': 296,
#   'Education': 89},
#  {'Shopping': 132,
#   'Food & Drink': 231,
#   'Life & Entertainment': 18,
#   'Vehicle': 89,
#   'Housing': 296,
#   'Education': 89},
#  {'Shopping': 36,
#   'Food & Drink': 25,
#   'Life & Entertainment': 22,
#   'Vehicle': 11,
#   'Housing': 642,
#   'Education': 127},
#  {'Shopping': 90,
#   'Food & Drink': 94,
#   'Life & Entertainment': 18,
#   'Vehicle': 62,
#   'Housing': 456,
#   'Education': 147},
#  {'Shopping': 11,
#   'Food & Drink': 136,
#   'Life & Entertainment': 44,
#   'Vehicle': 106,
#   'Housing': 431,
#   'Education': 146},
#  {'Shopping': 111,
#   'Food & Drink': 9,
#   'Life & Entertainment': 100,
#   'Vehicle': 90,
#   'Housing': 448,
#   'Education': 116},
#  {'Shopping': 11,
#   'Food & Drink': 154,
#   'Life & Entertainment': 2,
#   'Vehicle': 91,
#   'Housing': 564,
#   'Education': 54},
#  {'Shopping': 10,
#   'Food & Drink': 11,
#   'Life & Entertainment': 44,
#   'Vehicle': 72,
#   'Housing': 659,
#   'Education': 84},
#  {'Shopping': 79,
#   'Food & Drink': 49,
#   'Life & Entertainment': 66,
#   'Vehicle': 88,
#   'Housing': 466,
#   'Education': 136},
#  {'Shopping': 4,
#   'Food & Drink': 59,
#   'Life & Entertainment': 91,
#   'Vehicle': 119,
#   'Housing': 539,
#   'Education': 79},
#  {'Shopping': 51,
#   'Food & Drink': 29,
#   'Life & Entertainment': 26,
#   'Vehicle': 197,
#   'Housing': 523,
#   'Education': 70},
#  {'Shopping': 5,
#   'Food & Drink': 195,
#   'Life & Entertainment': 110,
#   'Vehicle': 112,
#   'Housing': 349,
#   'Education': 128},
#  {'Shopping': 113,
#   'Food & Drink': 20,
#   'Life & Entertainment': 0,
#   'Vehicle': 32,
#   'Housing': 635,
#   'Education': 112},
#  {'Shopping': 29,
#   'Food & Drink': 170,
#   'Life & Entertainment': 149,
#   'Vehicle': 197,
#   'Housing': 376,
#   'Education': 48},
#  {'Shopping': 6,
#   'Food & Drink': 84,
#   'Life & Entertainment': 10,
#   'Vehicle': 74,
#   'Housing': 689,
#   'Education': 110},
#  {'Shopping': 76,
#   'Food & Drink': 98,
#   'Life & Entertainment': 90,
#   'Vehicle': 151,
#   'Housing': 463,
#   'Education': 115},
#  {'Shopping': 100,
#   'Food & Drink': 55,
#   'Life & Entertainment': 30,
#   'Vehicle': 139,
#   'Housing': 528,
#   'Education': 144},
#  {'Shopping': 122,
#   'Food & Drink': 140,
#   'Life & Entertainment': 13,
#   'Vehicle': 161,
#   'Housing': 432,
#   'Education': 131},
#  {'Shopping': 27,
#   'Food & Drink': 127,
#   'Life & Entertainment': 92,
#   'Vehicle': 193,
#   'Housing': 544,
#   'Education': 30},
#  {'Shopping': 5,
#   'Food & Drink': 231,
#   'Life & Entertainment': 17,
#   'Vehicle': 122,
#   'Housing': 565,
#   'Education': 77},
#  {'Shopping': 1,
#   'Food & Drink': 99,
#   'Life & Entertainment': 114,
#   'Vehicle': 150,
#   'Housing': 570,
#   'Education': 91},
#  {'Shopping': 104,
#   'Food & Drink': 72,
#   'Life & Entertainment': 65,
#   'Vehicle': 139,
#   'Housing': 595,
#   'Education': 52},
#  {'Shopping': 9,
#   'Food & Drink': 217,
#   'Life & Entertainment': 28,
#   'Vehicle': 146,
#   'Housing': 594,
#   'Education': 40},
#  {'Shopping': 40,
#   'Food & Drink': 247,
#   'Life & Entertainment': 98,
#   'Vehicle': 17,
#   'Housing': 603,
#   'Education': 32},
#  {'Shopping': 21,
#   'Food & Drink': 98,
#   'Life & Entertainment': 130,
#   'Vehicle': 200,
#   'Housing': 501,
#   'Education': 97},
#  {'Shopping': 44,
#   'Food & Drink': 48,
#   'Life & Entertainment': 148,
#   'Vehicle': 75,
#   'Housing': 676,
#   'Education': 60},
#  {'Shopping': 24,
#   'Food & Drink': 139,
#   'Life & Entertainment': 89,
#   'Vehicle': 88,
#   'Housing': 654,
#   'Education': 73},
#  {'Shopping': 132,
#   'Food & Drink': 145,
#   'Life & Entertainment': 117,
#   'Vehicle': 8,
#   'Housing': 620,
#   'Education': 48},
#  {'Shopping': 68,
#   'Food & Drink': 110,
#   'Life & Entertainment': 92,
#   'Vehicle': 114,
#   'Housing': 588,
#   'Education': 101},
#  {'Shopping': 66,
#   'Food & Drink': 228,
#   'Life & Entertainment': 76,
#   'Vehicle': 141,
#   'Housing': 504,
#   'Education': 75},
#  {'Shopping': 94,
#   'Food & Drink': 229,
#   'Life & Entertainment': 103,
#   'Vehicle': 63,
#   'Housing': 509,
#   'Education': 131},
#  {'Shopping': 118,
#   'Food & Drink': 42,
#   'Life & Entertainment': 96,
#   'Vehicle': 173,
#   'Housing': 603,
#   'Education': 108},
#  {'Shopping': 56,
#   'Food & Drink': 244,
#   'Life & Entertainment': 132,
#   'Vehicle': 75,
#   'Housing': 541,
#   'Education': 97},
#  {'Shopping': 132,
#   'Food & Drink': 231,
#   'Life & Entertainment': 18,
#   'Vehicle': 89,
#   'Housing': 296,
#   'Education': 89},
#  {'Shopping': 60,
#   'Food & Drink': 116,
#   'Life & Entertainment': 20,
#   'Vehicle': 67,
#   'Housing': 106,
#   'Education': 50}]

# %%
# Keep only the best chromosomes in the population
population = sorted(population, key=lambda x: fitness(x, budget), reverse=True)[:population_size]

# %%
best_chromosome = None
if best_chromosome is None or fitness(best_chromosome, budget) < fitness(population[0], budget):
    best_chromosome = population[0]
    print(best_chromosome)
# Out:
# {'Shopping': 4, 'Food & Drink': 25, 'Life & Entertainment': 25, 'Vehicle': 70, 'Housing': 21, 'Education': 11}

# %%
# Example usage
budget = 1500
population_size = 100
generations = 100
mutation_rate = 0.1
best_chromosome = genetic_algorithm(budget, population_size, generations, mutation_rate)
print(f"Best chromosome: {best_chromosome}, Fitness: {fitness(best_chromosome, budget)}")
# Out:
# Generation 1: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 2: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 3: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 4: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 5: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 6: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 7: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 8: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 9: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 10: Best chromosome = {'Shopping': 3, 'Food & Drink': 259, 'Life & Entertainment': 113, 'Vehicle': 289, 'Housing': 258, 'Education': 6}, Fitness = 0.38133333333333336
# Generation 11: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 12: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 13: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 14: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 15: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 16: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 17: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 18: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 19: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 20: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 21: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 22: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 23: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 24: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 25: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 26: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 27: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 28: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 29: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 30: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 31: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 32: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 33: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 34: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 35: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 36: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 37: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 38: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 39: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 40: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 41: Best chromosome = {'Shopping': 4, 'Food & Drink': 281, 'Life & Entertainment': 113, 'Vehicle': 204, 'Housing': 285, 'Education': 18}, Fitness = 0.39666666666666667
# Generation 42: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 43: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 44: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 45: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 46: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 47: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 48: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 49: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 50: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 51: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 52: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 53: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 54: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 55: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 56: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 57: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 58: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 59: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 60: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 61: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 62: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 63: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 64: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 65: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 66: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 67: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 68: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 69: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 70: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 71: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 72: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 73: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 74: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 75: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 76: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 77: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 78: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 79: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 80: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 81: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 82: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 83: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 84: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 85: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 86: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 87: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 88: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 89: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 90: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 91: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 18}, Fitness = 0.4053333333333333
# Generation 92: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 93: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 94: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 95: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 96: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 97: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 98: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 99: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Generation 100: Best chromosome = {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness = 0.41333333333333333
# Best chromosome: {'Shopping': 23, 'Food & Drink': 254, 'Life & Entertainment': 113, 'Vehicle': 199, 'Housing': 285, 'Education': 6}, Fitness: 0.41333333333333333

# %%
balance = budget - sum(best_chromosome.values())
balance
# Out:
# 620
